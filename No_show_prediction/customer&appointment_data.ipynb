# %%
import pandas as pd
import random as rd
import warnings
warnings.filterwarnings('ignore')

# %%
path = "C:\\Users\\ritaf\\Documents\\ESTUDOS\\NOVA IMS\\3º Ano\\Capstone Project\\Projeto\\"
appointment = pd.read_csv(path + 'no_show.csv')
customer = pd.read_csv(path + 'customer_data.csv')

# %%
appointment = appointment.sample(n=150, replace=False)

# %%
# TEM O APPOINTMENT ID A MAIS
features = ['AppointmentID', 'AppointmentWeekNumber', 'AppointmentDayOfMonth', 'AppointmentHour', 'WeekendConsults', 'WeekdayConsults', 'Adults', 'Children', 'Babies', 'AffiliatedPatient', 'PreviousAppointments', 'PreviousNoShows', 'LastMinutesLate', 'OnlineBooking', 'AppointmentChanges', 'BookingToConsultDays', 'ParkingSpaceBooked', 'SpecialRequests', 'NoInsurance', 'ExtraExamsPerConsult', 'DoctorAssigned', 'ConsultPriceEuros', '%PaidinAdvance', 'CountryofOriginHDI (Year-1)']
appointment = appointment.loc[:, features]
appointment.head()
# Out:
#        AppointmentID  AppointmentWeekNumber  AppointmentDayOfMonth  \
# 7447           39447                     37                      6
# 13693          35891                     50                      8
# 2313           21065                      4                     18
# 9675           15297                     45                     30
# 4801           37031                     42                     12
#
#        AppointmentHour  WeekendConsults  WeekdayConsults  Adults  Children  \
# 7447             19.25                0                5       1       0.0
# 13693            21.50                0                1       2       0.0
# 2313             22.00                1                4       1       0.0
# 9675             23.00                2                1       2       0.0
# 4801             21.25                0                3       2       0.0
#
#        Babies  AffiliatedPatient  ...  AppointmentChanges  \
# 7447        0                  0  ...                   0
# 13693       0                  0  ...                   0
# 2313        0                  0  ...                   2
# 9675        0                  0  ...                   0
# 4801        0                  0  ...                   0
#
#        BookingToConsultDays  ParkingSpaceBooked  SpecialRequests  NoInsurance  \
# 7447                    230                   0                0            0
# 13693                    71                   0                1            0
# 2313                    150                   0                0            0
# 9675                    154                   0                2            0
# 4801                      2                   0                0            0
#
#        ExtraExamsPerConsult  DoctorAssigned  ConsultPriceEuros  \
# 7447                      1               6             111.00
# 13693                     0               6              79.20
# 2313                      1               6              80.00
# 9675                      1               3             104.10
# 4801                      1               3             163.33
#
#        %PaidinAdvance  CountryofOriginHDI (Year-1)
# 7447              0.0                        0.842
# 13693             0.0                        0.918
# 2313              0.0                        0.842
# 9675              0.0                        0.913
# 4801              0.0                        0.885
#
# [5 rows x 24 columns]

# %%
appointment.reset_index(drop=True, inplace=True)

# %%
complete = pd.concat([appointment, customer], axis=1)
complete
# Out:
#      AppointmentID  AppointmentWeekNumber  AppointmentDayOfMonth  \
# 0            39447                     37                      6
# 1            35891                     50                      8
# 2            21065                      4                     18
# 3            15297                     45                     30
# 4            37031                     42                     12
# ..             ...                    ...                    ...
# 145          33018                     14                     29
# 146          20664                     48                     23
# 147          27443                     15                      5
# 148          17909                     40                     25
# 149          15154                     34                     14
#
#      AppointmentHour  WeekendConsults  WeekdayConsults  Adults  Children  \
# 0              19.25                0                5       1       0.0
# 1              21.50                0                1       2       0.0
# 2              22.00                1                4       1       0.0
# 3              23.00                2                1       2       0.0
# 4              21.25                0                3       2       0.0
# ..               ...              ...              ...     ...       ...
# 145            15.75                0                4       2       2.0
# 146            15.75                0                4       2       0.0
# 147            19.50                0                3       3       0.0
# 148            19.75                2                2       3       0.0
# 149            15.25                1                0       2       1.0
#
#      Babies  AffiliatedPatient  ...  DoctorAssigned  ConsultPriceEuros  \
# 0         0                  0  ...               6             111.00
# 1         0                  0  ...               6              79.20
# 2         0                  0  ...               6              80.00
# 3         0                  0  ...               3             104.10
# 4         0                  0  ...               3             163.33
# ..      ...                ...  ...             ...                ...
# 145       0                  0  ...               1             216.00
# 146       0                  0  ...               6              88.40
# 147       0                  0  ...               3             105.00
# 148       0                  0  ...               3             144.76
# 149       0                  0  ...               6             134.10
#
#      %PaidinAdvance  CountryofOriginHDI (Year-1)  PatientID  FirstName  \
# 0               0.0                        0.842          1       John
# 1               0.0                        0.918          2       Jane
# 2               0.0                        0.842          3     Robert
# 3               0.0                        0.913          4      Alice
# 4               0.0                        0.885          5    Michael
# ..              ...                          ...        ...        ...
# 145             0.0                        0.918        146      Karen
# 146             0.0                        0.933        147     Joseph
# 147             0.0                        0.913        148      Laura
# 148             0.0                        0.918        149    William
# 149             0.0                        0.813        150       Mary
#
#      LastName                     Email  Age         Username
# 0         Doe         johndoe@email.com   35        johndoe35
# 1       Smith       janesmith@email.com   28      janesmith28
# 2     Johnson   robertjohnson@email.com   42        robjohn42
# 3    Williams   alicewilliams@email.com   31  alicewilliams31
# 4       Brown    michaelbrown@email.com   45      mikebrown45
# ..        ...                       ...  ...              ...
# 145    Martin     karenmartin@email.com   45         karenm45
# 146  Anderson  josephanderson@email.com   36        josepha36
# 147     Perez      lauraperez@email.com   31         laurap31
# 148     Jones    williamjones@email.com   47       williamj47
# 149      Hill        maryhill@email.com   32          maryh32
#
# [150 rows x 30 columns]

# %%
complete.columns
# Out:
# Index(['AppointmentID', 'AppointmentWeekNumber', 'AppointmentDayOfMonth',
#        'AppointmentHour', 'WeekendConsults', 'WeekdayConsults', 'Adults',
#        'Children', 'Babies', 'AffiliatedPatient', 'PreviousAppointments',
#        'PreviousNoShows', 'LastMinutesLate', 'OnlineBooking',
#        'AppointmentChanges', 'BookingToConsultDays', 'ParkingSpaceBooked',
#        'SpecialRequests', 'NoInsurance', 'ExtraExamsPerConsult',
#        'DoctorAssigned', 'ConsultPriceEuros', '%PaidinAdvance',
#        'CountryofOriginHDI (Year-1)', 'PatientID', 'FirstName', 'LastName',
#        'Email', 'Age', 'Username'],
#       dtype='object')

# %%
patients = complete[['PatientID', 'FirstName', 'LastName', 'Email', 'Age', 'Username', 'WeekendConsults', 'WeekdayConsults', 'Adults', 'Children', 'Babies', 'AffiliatedPatient', 'PreviousAppointments', 'PreviousNoShows', 'LastMinutesLate', 'NoInsurance', 'ExtraExamsPerConsult', 'CountryofOriginHDI (Year-1)']]

# %%
appointments = complete[['AppointmentID', 'AppointmentWeekNumber', 'AppointmentDayOfMonth', 'AppointmentHour', 'WeekendConsults', 'WeekdayConsults', 'Adults', 'Children', 'Babies', 'AffiliatedPatient', 'PreviousAppointments', 'PreviousNoShows', 'LastMinutesLate', 'OnlineBooking', 'AppointmentChanges', 'BookingToConsultDays', 'ParkingSpaceBooked', 'SpecialRequests', 'NoInsurance', 'ExtraExamsPerConsult', 'DoctorAssigned', 'ConsultPriceEuros', '%PaidinAdvance', 'CountryofOriginHDI (Year-1)', 'PatientID']]
appointments.set_index('AppointmentID', inplace=True)

# %%
appointments
# Out:
#                AppointmentWeekNumber  AppointmentDayOfMonth  AppointmentHour  \
# AppointmentID
# 39447                             37                      6            19.25
# 35891                             50                      8            21.50
# 21065                              4                     18            22.00
# 15297                             45                     30            23.00
# 37031                             42                     12            21.25
# ...                              ...                    ...              ...
# 33018                             14                     29            15.75
# 20664                             48                     23            15.75
# 27443                             15                      5            19.50
# 17909                             40                     25            19.75
# 15154                             34                     14            15.25
#
#                WeekendConsults  WeekdayConsults  Adults  Children  Babies  \
# AppointmentID
# 39447                        0                5       1       0.0       0
# 35891                        0                1       2       0.0       0
# 21065                        1                4       1       0.0       0
# 15297                        2                1       2       0.0       0
# 37031                        0                3       2       0.0       0
# ...                        ...              ...     ...       ...     ...
# 33018                        0                4       2       2.0       0
# 20664                        0                4       2       0.0       0
# 27443                        0                3       3       0.0       0
# 17909                        2                2       3       0.0       0
# 15154                        1                0       2       1.0       0
#
#                AffiliatedPatient  PreviousAppointments  ...  \
# AppointmentID                                           ...
# 39447                          0                     0  ...
# 35891                          0                     0  ...
# 21065                          0                     0  ...
# 15297                          0                     0  ...
# 37031                          0                     0  ...
# ...                          ...                   ...  ...
# 33018                          0                     0  ...
# 20664                          0                     0  ...
# 27443                          0                     0  ...
# 17909                          0                     0  ...
# 15154                          0                     0  ...
#
#                BookingToConsultDays  ParkingSpaceBooked  SpecialRequests  \
# AppointmentID
# 39447                           230                   0                0
# 35891                            71                   0                1
# 21065                           150                   0                0
# 15297                           154                   0                2
# 37031                             2                   0                0
# ...                             ...                 ...              ...
# 33018                            25                   0                0
# 20664                            67                   0                2
# 27443                            54                   0                1
# 17909                            43                   0                1
# 15154                            86                   0                0
#
#                NoInsurance  ExtraExamsPerConsult  DoctorAssigned  \
# AppointmentID
# 39447                    0                     1               6
# 35891                    0                     0               6
# 21065                    0                     1               6
# 15297                    0                     1               3
# 37031                    0                     1               3
# ...                    ...                   ...             ...
# 33018                    0                     1               1
# 20664                    0                     1               6
# 27443                    0                     1               3
# 17909                    0                     2               3
# 15154                    0                     1               6
#
#                ConsultPriceEuros  %PaidinAdvance  CountryofOriginHDI (Year-1)  \
# AppointmentID
# 39447                     111.00             0.0                        0.842
# 35891                      79.20             0.0                        0.918
# 21065                      80.00             0.0                        0.842
# 15297                     104.10             0.0                        0.913
# 37031                     163.33             0.0                        0.885
# ...                          ...             ...                          ...
# 33018                     216.00             0.0                        0.918
# 20664                      88.40             0.0                        0.933
# 27443                     105.00             0.0                        0.913
# 17909                     144.76             0.0                        0.918
# 15154                     134.10             0.0                        0.813
#
#                PatientID
# AppointmentID
# 39447                  1
# 35891                  2
# 21065                  3
# 15297                  4
# 37031                  5
# ...                  ...
# 33018                146
# 20664                147
# 27443                148
# 17909                149
# 15154                150
#
# [150 rows x 24 columns]

# %% [markdown]
# NOTAS:
# - children está como float, não sei se isso vai ser um problema
# - appointment hour está tipo: 17.75 que é 17h45
# - para chegarmos ao appointment week number através da data
#     - date_object = datetime.strptime(date_string, '%Y-%m-%d')
#     - week_number = date_object.strftime('%W')    o chatgpt disse %V
# - id dos medicos é um bocado estranho... por haver -1
# - hdi temos de fazer a conversão ... acho que pode ser logo no botão... "se ele escolher isto, isto acontece2 com um if
# - temos de aplicar robust scaler nas previsões
# - dados perguntados ou não ao utilizador:
#     - Sim: 'AppointmentWeekNumber', 'AppointmentDayOfMonth', 'AppointmentHour', 'AppointmentChanges', 'ParkingSpaceBooked', 'SpecialRequests', 'DoctorAssigned', '%PaidinAdvance'
#     - Não (já temos): 'WeekendConsults', 'WeekdayConsults', 'Adults', 'Children', 'Babies', 'AffiliatedPatient', 'PreviousAppointments', 'PreviousNoShows', 'LastMinutesLate', 'NoInsurance', 'ExtraExamsPerConsult', 'CountryofOriginHDI (Year-1)'? , 'PatientID'
#     - Não (calculados): 'ConsultPriceEuros', 'OnlineBooking', 'BookingToConsultDays', 'CountryofOriginHDI (Year-1)'?
